# %% [markdown]
# # SleepSense: Unveiling the secrets of sleep and Lifestyle
#
#
#
#                                                                             - Author: NagaCharitavya Madala

# %% [markdown]
# * Dataset is from: [Kaggle.com] (https://www.kaggle.com/)

# %% [markdown]
# #### Steps of project development:
#
# - 1. read dataset
# - 2. apply basic functions
# - 3. data Cleaning
# - 4. data Filtering
# - 5. Grouping
# - 6. Sorting
# - 7. Aggregations(min,max,mean,mode,variance)
# - 8. Data Visualization

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading dataset

# %%
# To read the .csv file
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ### Applying Basic functions

# %%
## to understand the data better see the top rows
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
## to understand the data better see the bottom rows
df.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# To know the shape that means rows and columns in no?
df.shape
# Out:
# (374, 13)

# %%
# To know the column names to understand in better way.
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
# Average age of individuals
avg_age = df['Age'].mean()
print("Average Age:", avg_age)
# Out:
# Average Age: 42.18449197860963

# %%
# Occupation with highest average physical activity level
occupation_avg_activity = df.groupby('Occupation')['Physical Activity Level'].mean()
highest_activity_occupation = occupation_avg_activity.idxmax()
print("Occupation with Highest Average Activity:", highest_activity_occupation)
# Out:
# Occupation with Highest Average Activity: Nurse

# %%
# Top 5 individuals with highest quality of sleep
top_quality_sleep = df.nlargest(5, 'Quality of Sleep')
print("Top 5 Quality of Sleep:\n", top_quality_sleep)
# Out:
# Top 5 Quality of Sleep:
#       Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 149        150  Female   39  Accountant             8.0                 9
# 150        151  Female   39  Accountant             8.0                 9
# 276        277    Male   49      Doctor             8.1                 9
# 277        278    Male   49      Doctor             8.1                 9
# 279        280  Female   50    Engineer             8.3                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 149                       80             3  Normal Weight         115/78
# 150                       80             3  Normal Weight         115/78
# 276                       85             3          Obese         139/91
# 277                       85             3          Obese         139/91
# 279                       30             3         Normal         125/80
#
#      Heart Rate  Daily Steps Sleep Disorder
# ...

# %%
# Individuals with sleep disorder and are doctors
sleep_disorder_doctors = df[(df['Sleep Disorder'] == 'Sleep Apnea') & (df['Occupation'] == 'Doctor')]
print("Doctors with Sleep Disorder:\n", sleep_disorder_doctors)
# Out:
# Doctors with Sleep Disorder:
#       Person ID Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 17          18   Male   29     Doctor             6.0                 6
# 49          50   Male   31     Doctor             7.7                 7
# 276        277   Male   49     Doctor             8.1                 9
# 277        278   Male   49     Doctor             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 17                        30             8       Normal         120/80
# 49                        75             6       Normal         120/80
# 276                       85             3        Obese         139/91
# 277                       85             3        Obese         139/91
#
#      Heart Rate  Daily Steps Sleep Disorder
# 17           70         8000    Sleep Apnea
# 49           70         8000    Sleep Apnea
# 276          86         3700    Sleep Apnea
# ...

# %%
# Correlation between sleep duration and stress level
correlation = df['Sleep Duration'].corr(df['Stress Level'])
print("Correlation between Sleep Duration and Stress Level:", correlation)
# Out:
# Correlation between Sleep Duration and Stress Level: -0.8110230278940451

# %%
# Average heart rate for males and females
avg_heart_rate_gender = df.groupby('Gender')['Heart Rate'].mean()
print("Average Heart Rate by Gender:\n", avg_heart_rate_gender)
# Out:
# Average Heart Rate by Gender:
#  Gender
# Female    69.259459
# Male      71.052910
# Name: Heart Rate, dtype: float64

# %%
# To count the number of females and males are suffering with this?
df['Gender'].value_counts()
# Out:
# Male      189
# Female    185
# Name: Gender, dtype: int64

# %%
# To print the only male records..
df[df["Gender"]=="Male"]
# Out:
#      Person ID Gender  Age            Occupation  Sleep Duration  \
# 0            1   Male   27     Software Engineer             6.1
# 1            2   Male   28                Doctor             6.2
# 2            3   Male   28                Doctor             6.2
# 3            4   Male   28  Sales Representative             5.9
# 4            5   Male   28  Sales Representative             5.9
# ..         ...    ...  ...                   ...             ...
# 249        250   Male   44           Salesperson             6.5
# 264        265   Male   48                Doctor             7.3
# 266        267   Male   48                Doctor             7.3
# 276        277   Male   49                Doctor             8.1
# 277        278   Male   49                Doctor             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# To print the only female records..
df[df["Gender"]=="Female"]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 16          17  Female   29      Nurse             6.5                 5
# 18          19  Female   29      Nurse             6.5                 5
# 30          31  Female   30      Nurse             6.4                 5
# 31          32  Female   30      Nurse             6.4                 5
# 32          33  Female   31      Nurse             7.9                 8
# ..         ...     ...  ...        ...             ...               ...
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
# To count the numbers in specific job role
df['Occupation'].value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
# To print only Overweight title records.
df[df["BMI Category"] == "Overweight"]
print(df[df["BMI Category"] == "Overweight"])
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 68          69  Female   33          Scientist             6.2
# 69          70  Female   33          Scientist             6.2
# 80          81  Female   34          Scientist             5.8
# 81          82  Female   34          Scientist             5.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# 373        374  Female   59              Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# To find the mean,max,min,std,count
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %% [markdown]
# #### Statistical functions

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.max()
# Out:
# Person ID                          374
# Gender                            Male
# Age                                 59
# Occupation                     Teacher
# Sleep Duration                     8.5
# Quality of Sleep                     9
# Physical Activity Level             90
# Stress Level                         8
# BMI Category                Overweight
# Blood Pressure                  142/92
# Heart Rate                          86
# Daily Steps                      10000
# Sleep Disorder             Sleep Apnea
# dtype: object

# %%
df.min()
# Out:
# Person ID                           1
# Gender                         Female
# Age                                27
# Occupation                 Accountant
# Sleep Duration                    5.8
# Quality of Sleep                    4
# Physical Activity Level            30
# Stress Level                        3
# BMI Category                   Normal
# Blood Pressure                 115/75
# Heart Rate                         65
# Daily Steps                      3000
# Sleep Disorder               Insomnia
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15620\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Person ID                   187.500000
# Age                          42.184492
# Sleep Duration                7.132086
# Quality of Sleep              7.312834
# Physical Activity Level      59.171123
# Stress Level                  5.385027
# Heart Rate                   70.165775
# Daily Steps                6816.844920
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15620\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Person ID                  1.168750e+04
# Age                        7.522324e+01
# Sleep Duration             6.330696e-01
# Quality of Sleep           1.432703e+00
# Physical Activity Level    4.339224e+02
# Stress Level               3.148944e+00
# Heart Rate                 1.710381e+01
# Daily Steps                2.617651e+06
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15620\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Person ID                   108.108742
# Age                           8.673133
# Sleep Duration                0.795657
# Quality of Sleep              1.196956
# Physical Activity Level      20.830804
# Stress Level                  1.774526
# Heart Rate                    4.135676
# Daily Steps                1617.915679
# dtype: float64

# %% [markdown]
# #### Aggregations

# %%
df.agg([np.mean,np.median,np.amax])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15620\174014042.py:1: FutureWarning: ['Gender', 'Occupation', 'BMI Category', 'Blood Pressure', 'Sleep Disorder'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg([np.mean,np.median,np.amax])
#         Person ID Gender        Age Occupation  Sleep Duration  \
# mean        187.5    NaN  42.184492        NaN        7.132086
# median      187.5    NaN  43.000000        NaN        7.200000
# amax        374.0   Male  59.000000    Teacher        8.500000
#
#         Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# mean            7.312834                59.171123      5.385027          NaN
# median          7.000000                60.000000      5.000000          NaN
# amax            9.000000                90.000000      8.000000   Overweight
#
#        Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# ...

# %% [markdown]
# ### Data cleaning:
# - 1.isnull() : TO check the data having null values or not.
# - 2.notnull(): To get the not null values.
# - 3.dropna(): To remove the null values.
# - 4.fillna(): To fill the null values with meaningfull data.
# - 5.replace(): To replace the data
# - 6.sort_values(): To sort the data
# - 7.NaN : Not a number

# %%
#1. isnull() : TO check the data having null values
df.isnull()
# Out:
#      Person ID  Gender    Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0        False   False  False       False           False             False
# 1        False   False  False       False           False             False
# 2        False   False  False       False           False             False
# 3        False   False  False       False           False             False
# 4        False   False  False       False           False             False
# ..         ...     ...    ...         ...             ...               ...
# 369      False   False  False       False           False             False
# 370      False   False  False       False           False             False
# 371      False   False  False       False           False             False
# 372      False   False  False       False           False             False
# 373      False   False  False       False           False             False
#
# ...

# %%
# To print the number of null values
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
# To print the only null value records
df[df.isnull().any(axis=1)]
#print(len(df[df.isnull().any(axis=1)]))
# Out:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []

# %%
#2. To print the notnull()
df.notnull()
# Out:
#      Person ID  Gender   Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         True    True  True        True            True              True
# 1         True    True  True        True            True              True
# 2         True    True  True        True            True              True
# 3         True    True  True        True            True              True
# 4         True    True  True        True            True              True
# ..         ...     ...   ...         ...             ...               ...
# 369       True    True  True        True            True              True
# 370       True    True  True        True            True              True
# 371       True    True  True        True            True              True
# 372       True    True  True        True            True              True
# 373       True    True  True        True            True              True
#
# ...

# %%
# To count the not null records?
df.notnull().sum()
# Out:
# Person ID                  374
# Gender                     374
# Age                        374
# Occupation                 374
# Sleep Duration             374
# Quality of Sleep           374
# Physical Activity Level    374
# Stress Level               374
# BMI Category               374
# Blood Pressure             374
# Heart Rate                 374
# Daily Steps                374
# Sleep Disorder             374
# dtype: int64

# %%
print(len(df.notnull()))
# Out:
# 374

# %%
# To print the not null records.
df[df.notnull().all(axis=1)]
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#3. dropna(): To remove the null values..
df.dropna()
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#4. fillna(): To fill the null values with meaningfull data.
df.fillna('missing_value',inplace=True)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %% [markdown]
# ### This datset has no null values upto now data cleaning process is completed

# %% [markdown]
# ### Unique() and Value_counts()

# %%
df['BMI Category'].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
df['BMI Category'].value_counts()
# Out:
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: BMI Category, dtype: int64

# %%
df['Blood Pressure'].unique()
# Out:
# array(['126/83', '125/80', '140/90', '120/80', '132/87', '130/86',
#        '117/76', '118/76', '128/85', '131/86', '128/84', '115/75',
#        '135/88', '129/84', '130/85', '115/78', '119/77', '121/79',
#        '125/82', '135/90', '122/80', '142/92', '140/95', '139/91',
#        '118/75'], dtype=object)

# %%
df['Blood Pressure'].value_counts()
# Out:
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     4
# 132/87     3
# 128/85     3
# 126/83     2
# 115/78     2
# 139/91     2
# 142/92     2
# 119/77     2
# 135/88     2
# 129/84     2
# 128/84     2
# 131/86     2
# 117/76     2
# 130/86     2
# 118/75     2
# 121/79     1
# 122/80     1
# 118/76     1
# Name: Blood Pressure, dtype: int64

# %%
df['Stress Level'].unique()
# Out:
# array([6, 8, 7, 4, 3, 5], dtype=int64)

# %%
df['Stress Level'].value_counts()
# Out:
# 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# 6    46
# Name: Stress Level, dtype: int64

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['None', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df['Sleep Disorder'].value_counts()
# Out:
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %% [markdown]
# ### Grouping: It is used to group the data

# %%
gp = df.groupby('Occupation')
gp

# %%
gp.ngroups
# Out:
# 11

# %%
# To print only single group name records
gp.get_group('Nurse')
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 16          17  Female   29      Nurse             6.5                 5
# 18          19  Female   29      Nurse             6.5                 5
# 30          31  Female   30      Nurse             6.4                 5
# 31          32  Female   30      Nurse             6.4                 5
# 32          33  Female   31      Nurse             7.9                 8
# ..         ...     ...  ...        ...             ...               ...
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# ...

# %%
df[(df['Occupation']=='Nurse') & (df['BMI Category']=='Normal Weight')]
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 16          17  Female   29      Nurse             6.5                 5
# 18          19  Female   29      Nurse             6.5                 5
# 30          31  Female   30      Nurse             6.4                 5
# 31          32  Female   30      Nurse             6.4                 5
# 32          33  Female   31      Nurse             7.9                 8
# 125        126  Female   37      Nurse             7.5                 8
# 302        303  Female   51      Nurse             7.1                 7
#
#      Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 16                        40             7  Normal Weight         132/87
# 18                        40             7  Normal Weight         132/87
# 30                        35             7  Normal Weight         130/86
# 31                        35             7  Normal Weight         130/86
# ...

# %% [markdown]
# ### Sorting the data set using sleep duration
# * the top city will be having highest in cases
# * Functions used sort_values()
# * sorted the data based on sleep duration,quality of sleep

# %%
df1 = df.sort_values(by='Sleep Duration', ascending=False)
df1
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 299        300  Female   51              Engineer             8.5
# 316        317  Female   53              Engineer             8.5
# 327        328  Female   53              Engineer             8.5
# 298        299  Female   51              Engineer             8.5
# 325        326  Female   53              Engineer             8.5
# ..         ...     ...  ...                   ...             ...
# 4            5    Male   28  Sales Representative             5.9
# 3            4    Male   28  Sales Representative             5.9
# 265        266  Female   48                 Nurse             5.9
# 80          81  Female   34             Scientist             5.8
# 81          82  Female   34             Scientist             5.8
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 299                 9                       30             3       Normal
# ...

# %%
df2 = df.sort_values(by='Sleep Duration', ascending=True)
df2
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 81          82  Female   34             Scientist             5.8
# 80          81  Female   34             Scientist             5.8
# 265        266  Female   48                 Nurse             5.9
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 327        328  Female   53              Engineer             8.5
# 330        331  Female   53              Engineer             8.5
# 329        330  Female   53              Engineer             8.5
# 338        339  Female   54              Engineer             8.5
# 301        302  Female   51              Engineer             8.5
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 81                  4                       32             8   Overweight
# ...

# %%
df3 = df.sort_values(by='Blood Pressure', ascending=False)
df3
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 264        265    Male   48      Doctor             7.3                 7
# 266        267    Male   48      Doctor             7.3                 7
# 373        374  Female   59       Nurse             8.1                 9
# 297        298  Female   50       Nurse             6.1                 6
# 291        292  Female   50       Nurse             6.1                 6
# ..         ...     ...  ...         ...             ...               ...
# 99         100  Female   36     Teacher             7.1                 8
# 98          99  Female   36     Teacher             7.1                 8
# 97          98  Female   36  Accountant             7.1                 8
# 96          97  Female   36  Accountant             7.2                 8
# 133        134  Female   38  Accountant             7.1                 8
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df4 = df.sort_values(by='Daily Steps', ascending=False)
df4
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 281        282  Female   50                 Nurse             6.1
# 297        298  Female   50                 Nurse             6.1
# 269        270  Female   49                 Nurse             6.1
# 267        268  Female   49                 Nurse             6.2
# 265        266  Female   48                 Nurse             5.9
# ..         ...     ...  ...                   ...             ...
# 93          94    Male   35                Lawyer             7.4
# 145        146  Female   38                Lawyer             7.4
# 5            6    Male   28     Software Engineer             5.9
# 4            5    Male   28  Sales Representative             5.9
# 3            4    Male   28  Sales Representative             5.9
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 281                 6                       90             8   Overweight
# ...

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ## Visualization:
# - 1.Matplotlib
# - 2.Seaborn

# %% [markdown]
# ## Installing matplotlib

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mpl

# %% [markdown]
# ### Bar chart
# - with pyplot,we can use bar() to draw bar graphs
# - The bar() takes arguments that describes the layout of the bars
# - The categories and their values represented by first and second argument as array
# - plt.bar()

# %%
plt.bar(df['Sleep Disorder'],df['Sleep Duration'])
# Out:
# <BarContainer object of 374 artists>

# %% [markdown]
# ## Horizontal Bar Graph
# plt.barh()

# %%
plt.barh(df['Stress Level'],df['Heart Rate'])
# Out:
# <BarContainer object of 374 artists>

# %% [markdown]
# ### Scatter plot
# - scatter plot is a diagram where each value i data set is represented by a dot
# - the purpose of scatter plot is to display what happens to one variable when another variable is changed (relationship b/w two quantitive variables)
# - plt.scatter()

# %%
plt.scatter(df['Age'],df['Sleep Duration'])

# %%
plt.plot(df['Age'],df['Sleep Duration'])

# %%
plt.scatter(df['Sleep Disorder'],df['Quality of Sleep'])

# %%
plt.plot(df['Sleep Disorder'],df['Quality of Sleep'])

# %% [markdown]
# ### Piechart
# - plt.pie()

# %%
category_counts = df['Sleep Disorder'].value_counts()

plt.figure(figsize=(8, 8))  # Set the figure size (optional)

# Plot the pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140,shadow=True)

# Add a title to the pie chart
plt.title('Distribution of Sleep Disorder')

# Show the pie chart
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
fig,ax=plt.subplots(figsize=(13,5))
sns.barplot(x=df['Age'],y=df['Quality of Sleep'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Quality of Sleep'>

# %% [markdown]
# ### Lineplot
# - sns.lineplot

# %%
sns.lineplot(x='Sleep Duration',y='Physical Activity Level',data=df)
# Out:
# <AxesSubplot:xlabel='Sleep Duration', ylabel='Physical Activity Level'>

# %% [markdown]
# ### Categorical distribution data
# - Boxplot

# %%
plt.figure(figsize=(10, 6))  # Set the figure size (optional)
sns.boxplot(x='Sleep Disorder', y='Sleep Duration', data=df)

# Add labels and title to the plot
plt.xlabel('X-axis Label (Categorical Column)')
plt.ylabel('Y-axis Label (Numerical Column)')
plt.title('Box Plot - Categorical Distribution Data')

# Show the boxplot
plt.show()

# %%
sns.boxplot(x=df['Stress Level'])
# Out:
# <AxesSubplot:xlabel='Stress Level'>

# %% [markdown]
# ### violin plot
# - Similar to boxplot

# %%
plt.figure(figsize=(10, 6))  # Set the figure size (optional)

sns.violinplot(x='Quality of Sleep', y='Heart Rate', data=df)

# Add labels and title to the plot
plt.xlabel('X-axis Label (Categorical Column)')
plt.ylabel('Y-axis Label (Numerical Column)')
plt.title('Violin Plot - Categorical Distribution Data')

# Show the violin plot
plt.show()

# %%
sns.violinplot(x=df['Sleep Duration'])
# Out:
# <AxesSubplot:xlabel='Sleep Duration'>

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x=df['Age'],y=df['Sleep Disorder'])

# %% [markdown]
# ### Histogram Plot

# %%
fig,ax=plt.subplots(figsize=(16,10))
sns.histplot(x=df['Physical Activity Level'],kde=True)
# Out:
# <AxesSubplot:xlabel='Physical Activity Level', ylabel='Count'>

# %% [markdown]
# ### Pairplot
# - It displays multiple plots at a time in a single graph
# - Pairwise Relationship
# - Bydefault it return scatterplot
# - sns.pairplot()

# %%
plt.figure(figsize=(10, 8))  # Set the figure size (optional)

# Use sns.pairplot() to create the pairplot
sns.pairplot(df)

# Show the pairplot
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
corr = df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## END OF THE PROJECT
